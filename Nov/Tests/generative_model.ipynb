# %% [markdown]
# # Testing the generative model

# %% [markdown]
# ## Code

# %% [markdown]
# ## Networks

# %% [markdown]
# ### Network 1:

# %% [markdown]
# ### Network 2:

# %% [markdown]
# ### Network 3:

# %% [markdown]
# ### Network 4:

# %% [markdown]
# ### Network 5:

# %% [markdown]
# ### Network 6:

# %% [markdown]
# ### Network 7:

# %% [markdown]
# ### Network 8:
